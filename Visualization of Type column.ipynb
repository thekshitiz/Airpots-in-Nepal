# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/airport-list.csv")
df.tail(10)
# Out:
#         id    ident            type                  name        latitude_deg  \
# 39   32209     VNRC   small_airport     Ramechhap Airport  27.393999099731445
# 40   32587     VNRP   small_airport         Rolpa Airport           28.267292
# 41   31110     VNSR   small_airport    Sanfebagar Airport           29.236629
# 42   32301     VNDT   small_airport  Silgadi Doti Airport  29.263099670410156
# 43   32588     VNTP   small_airport       Tikapur Airport             28.5219
# 44  308291     VNKL   small_airport  Kangel Danda Airport       27.4106333137
# 45  308292  NP-0001   small_airport   Kamal Bazar Airport             29.0531
# 46  308294     VNTH   small_airport    Thamkharka Airport            27.04787
# 47  315124     VNSB   small_airport    Syangboche Airport             27.8112
# 48  308293     VNTJ  medium_airport     Taplejung Airport             27.3509
#
#         longitude_deg elevation_ft continent iso_country iso_region  \
# 39   86.0614013671875         1555        AS          NP      NP-JA
# 40          82.756496         4100        AS          NP      NP-RA
# 41          81.215317         2280        AS          NP      NP-SE
# 42  80.93599700927734         2100        AS          NP      NP-SE
# 43             81.123          522        AS          NP      NP-SE
# 44      86.6465950012          NaN        AS          NP      NP-SA
# 45           81.34256         6440        AS          NP      NP-SE
# 46          86.858022         5240        AS          NP      NP-SA
# 47            86.7124        12400        AS          NP      NP-SA
# 48           87.69525         7990        AS          NP      NP-ME
#
#      municipality scheduled_service gps_code iata_code local_code home_link  \
# 39      Ramechhap                 0     VNRC       RHP        NaN       NaN
# 40          Rolpa                 0     VNRP       RPA        NaN       NaN
# 41     Sanfebagar                 0     VNSR       FEB        NaN       NaN
# 42   Silgadi Doti                 0     VNDT       SIH        NaN       NaN
# 43        Tikapur                 0     VNTP       TPU        NaN       NaN
# 44            NaN                 0     VNKL       NaN        NaN       NaN
# 45    Kamal Bazar                 0      NaN       NaN        NaN       NaN
# 46  Khotang Bazar                 0     VNTH       NaN        NaN       NaN
# 47  Namche Bazaar                 0     VNSB       SYH        NaN       NaN
# 48      Taplejung                 1     VNTJ       TPJ        NaN       NaN
#
#                                       wikipedia_link         keywords score  \
# 39                                               NaN              NaN    50
# 40                                               NaN              NaN    50
# 41   http://en.wikipedia.org/wiki/Sanfebagar_Airport              NaN    50
# 42                                               NaN              NaN    50
# 43     https://en.wikipedia.org/wiki/Tikapur_Airport              NaN    50
# 44                                               NaN              NaN     0
# 45                                               NaN              NaN     0
# 46                                               NaN              NaN     0
# 47  https://en.wikipedia.org/wiki/Syangboche_Airport        Syanboche     0
# 48    http://en.wikipedia.org/wiki/Taplejung_Airport  Suketar Airport     0
#
#                  last_updated
# 39  2008-12-30T09:26:23+00:00
# 40  2017-08-19T09:13:26+00:00
# 41  2017-08-19T09:18:22+00:00
# 42  2008-12-30T09:27:16+00:00
# 43  2015-12-04T00:08:55+00:00
# 44  2013-03-01T10:51:15+00:00
# 45  2013-03-02T11:30:55+00:00
# 46  2013-03-02T14:59:21+00:00
# 47  2015-08-06T18:51:17+00:00
# 48  2015-09-06T17:04:30+00:00

# %%
df.info
# Out:
# <bound method DataFrame.info of            id        ident                 type  \
# 0   #meta +id  #meta +code  #loc +airport +type
# 1       26596         VNKT        large_airport
# 2       28150         VNLK        small_airport
# 3       26598         VNPK       medium_airport
# 4       30707         VNBP        small_airport
# 5       26597         VNNG       medium_airport
# 6       30936         VNDP        small_airport
# 7       31712         VNJL        small_airport
# 8       32172         VNPL        small_airport
# 9       26599         VNSI        small_airport
# 10      26595         VNJP       medium_airport
# 11      30931         VNDG        small_airport
# 12     308298         VNJS        small_airport
# 13     315129      NP-0002        small_airport
# 14      26593         VNBW       medium_airport
# 15      26600         VNVT       medium_airport
# 16      26594         VNCG        small_airport
# 17      31892         VNMG        small_airport
# 18      35199       NP-MWP        small_airport
# 19      30106         VNMA        small_airport
# 20      32236         VNRK        small_airport
# 21      32237         VNRT        small_airport
# 22      31675         VNST        small_airport
# 23      32311         VNSK        small_airport
# 24      32463         VNTR        small_airport
# 25      30701         VNBL        small_airport
# 26      30753         VNBT        small_airport
# 27      30760         VNBG        small_airport
# 28      30761         VNBR        small_airport
# 29      30706         VNBJ        small_airport
# 30      30875         VNDL        small_airport
# 31      30913         VNDH        small_airport
# 32      32586         VNDR        small_airport
# 33      31532         VNGK        small_airport
# 34      31703         VNJI        small_airport
# 35      31802         VNLD        small_airport
# 36      31856         VNLT        small_airport
# 37      32706         VNMN        small_airport
# 38      32213         VNRB        small_airport
# 39      32209         VNRC        small_airport
# 40      32587         VNRP        small_airport
# 41      31110         VNSR        small_airport
# 42      32301         VNDT        small_airport
# 43      32588         VNTP        small_airport
# 44     308291         VNKL        small_airport
# 45     308292      NP-0001        small_airport
# 46     308294         VNTH        small_airport
# 47     315124         VNSB        small_airport
# 48     308293         VNTJ       medium_airport
#
#                                name        latitude_deg      longitude_deg  \
# 0               #loc +airport +name           #geo +lat          #geo +lon
# 1   Tribhuvan International Airport             27.6966            85.3591
# 2                     Lukla Airport  27.686899185180664  86.72969818115234
# 3                   Pokhara Airport  28.200899124145508  83.98210144042969
# 4                 Bharatpur Airport           27.678101          84.429398
# 5                 Nepalgunj Airport  28.103599548339844  81.66699981689453
# 6                     Dolpa Airport  28.985700607299805  82.81909942626953
# 7                     Jumla Airport             29.2742          82.193298
# 8                    Phaplu Airport           27.517787          86.584454
# 9                    Simara Airport  27.159500122070312   84.9801025390625
# 10                 Janakpur Airport  26.708799362199997      85.9224014282
# 11                 Tulsipur Airport  28.111099243164062  82.29419708251953
# 12                   Jomsom Airport           28.780426             83.723
# 13                  Thalchi Airport             29.5211            82.1468
# 14            Gautam Buddha Airport           27.505685          83.416293
# 15               Biratnagar Airport   26.48150062561035  87.26399993896484
# 16                Bhadrapur Airport       26.5708007812  88.07959747310001
# 17                 Meghauli Airport             27.5774           84.22875
# 18                 Mountain Airport                  28  85.33300018310547
# 19                   Manang Airport           28.641399          84.089203
# 20        Rukum Chaurjahari Airport           28.627001             82.195
# 21                 Rumjatar Airport  27.303499221801758  86.55039978027344
# 22                  Simikot Airport  29.971099853515625  81.81890106201172
# 23                  Surkhet Airport              28.586          81.636002
# 24              Tumling Tar Airport           27.315001          87.193298
# 25                  Baglung Airport  28.212799072265625  83.66629791259766
# 26                  Baitadi Airport  29.465299606323242  80.54920196533203
# 27                  Bajhang Airport  29.538999557495117   81.1854019165039
# 28                   Bajura Airport   29.50200080871582  81.66899871826172
# 29                  Bhojpur Airport   27.14739990234375  87.05079650878906
# 30                 Darchula Airport  29.669200897216797  80.54840087890625
# 31                Dhangarhi Airport  28.753299713134766  80.58190155029297
# 32                Dhorpatan Airport           28.492115          83.050644
# 33                Palungtar Airport             28.0385            84.4664
# 34                     Jiri Airport           27.626313          86.230581
# 35                Lamidanda Airport   27.25309944152832  86.66999816894531
# 36                 Langtang Airport  28.200000762939453  85.58300018310547
# 37            Mahendranagar Airport  28.963199615478516  80.14790344238281
# 38                 Rajbiraj Airport           26.510066          86.733902
# 39                Ramechhap Airport  27.393999099731445   86.0614013671875
# 40                    Rolpa Airport           28.267292          82.756496
# 41               Sanfebagar Airport           29.236629          81.215317
# 42             Silgadi Doti Airport  29.263099670410156  80.93599700927734
# 43                  Tikapur Airport             28.5219             81.123
# 44             Kangel Danda Airport       27.4106333137      86.6465950012
# 45              Kamal Bazar Airport             29.0531           81.34256
# 46               Thamkharka Airport            27.04787          86.858022
# 47               Syangboche Airport             27.8112            86.7124
# 48                Taplejung Airport             27.3509           87.69525
#
#            elevation_ft                 continent           iso_country  \
# 0   #geo +elevation +ft  #region +continent +code  #country +code +iso2
# 1                  4390                        AS                    NP
# 2                  9380                        AS                    NP
# 3                  2712                        AS                    NP
# 4                   600                        AS                    NP
# 5                   540                        AS                    NP
# 6                  8200                        AS                    NP
# 7                  7700                        AS                    NP
# 8                  7918                        AS                    NP
# 9                   450                        AS                    NP
# 10                  256                        AS                    NP
# 11                 2100                        AS                    NP
# 12                 8976                        AS                    NP
# 13                 8970                        AS                    NP
# 14                  358                        AS                    NP
# 15                  236                        AS                    NP
# 16                  300                        AS                    NP
# 17                  600                        AS                    NP
# 18                  NaN                        AS                    NP
# 19                11001                        AS                    NP
# 20                 2500                        AS                    NP
# 21                 4500                        AS                    NP
# 22                 9246                        AS                    NP
# 23                 2400                        AS                    NP
# 24                 1700                        AS                    NP
# 25                 3320                        AS                    NP
# 26                 4200                        AS                    NP
# 27                 4100                        AS                    NP
# 28                 4300                        AS                    NP
# 29                 4000                        AS                    NP
# 30                 2132                        AS                    NP
# 31                  690                        AS                    NP
# 32                 8950                        AS                    NP
# 33                 1500                        AS                    NP
# 34                 6000                        AS                    NP
# 35                 4100                        AS                    NP
# 36                12000                        AS                    NP
# 37                  650                        AS                    NP
# 38                  250                        AS                    NP
# 39                 1555                        AS                    NP
# 40                 4100                        AS                    NP
# 41                 2280                        AS                    NP
# 42                 2100                        AS                    NP
# 43                  522                        AS                    NP
# 44                  NaN                        AS                    NP
# 45                 6440                        AS                    NP
# 46                 5240                        AS                    NP
# 47                12400                        AS                    NP
# 48                 7990                        AS                    NP
#
#           iso_region              municipality   scheduled_service  \
# 0   #adm1 +code +iso  #loc +municipality +name  #status +scheduled
# 1              NP-BA                 Kathmandu                   1
# 2              NP-SA                     Lukla                   1
# 3              NP-GA                   Pokhara                   1
# 4              NP-NA                 Bharatpur                   1
# 5              NP-BH                 Nepalgunj                   1
# 6              NP-KA                     Dolpa                   1
# 7              NP-KA                     Jumla                   1
# 8              NP-SA                    Phaplu                   1
# 9              NP-NA                    Simara                   1
# 10             NP-JA                  Janakpur                   1
# 11             NP-RA                      Dang                   0
# 12             NP-DH                    Jomsom                   1
# 13             NP-KA        Rara National Park                   0
# 14             NP-LU                  Bhairawa                   1
# 15             NP-KO                Biratnagar                   1
# 16             NP-ME                 Bhadrapur                   1
# 17             NP-NA                  Meghauli                   1
# 18             NP-BA                  Mountain                   1
# 19             NP-GA                    Ngawal                   0
# 20             NP-RA                  Rukumkot                   1
# 21             NP-SA                  Rumjatar                   1
# 22             NP-KA                   Simikot                   1
# 23             NP-BH                   Surkhet                   1
# 24             NP-KO               Tumling Tar                   1
# 25             NP-DH                   Baglung                   0
# 26             NP-MA                   Baitadi                   0
# 27             NP-SE                   Bajhang                   0
# 28             NP-SE                    Bajura                   0
# 29             NP-KO                   Bhojpur                   0
# 30             NP-MA                  Darchula                   0
# 31             NP-BH                 Dhangarhi                   0
# 32             NP-DH                 Dhorpatan                   0
# 33             NP-GA                    Gorkha                   0
# 34             NP-JA                      Jiri                   0
# 35             NP-SA                 Lamidanda                   0
# 36             NP-BA                  Langtang                   0
# 37             NP-MA             Mahendranagar                   0
# 38             NP-SA                  Rajbiraj                   0
# 39             NP-JA                 Ramechhap                   0
# 40             NP-RA                     Rolpa                   0
# 41             NP-SE                Sanfebagar                   0
# 42             NP-SE              Silgadi Doti                   0
# 43             NP-SE                   Tikapur                   0
# 44             NP-SA                       NaN                   0
# 45             NP-SE               Kamal Bazar                   0
# 46             NP-SA             Khotang Bazar                   0
# 47             NP-SA             Namche Bazaar                   0
# 48             NP-ME                 Taplejung                   1
#
#                     gps_code                  iata_code  \
# 0   #loc +airport +code +gps  #loc +airport +code +iata
# 1                       VNKT                        KTM
# 2                       VNLK                        LUA
# 3                       VNPK                        PKR
# 4                       VNBP                        BHR
# 5                       VNNG                        KEP
# 6                       VNDP                        DOP
# 7                       VNJL                        JUM
# 8                       VNPL                        PPL
# 9                       VNSI                        SIF
# 10                      VNJP                        JKR
# 11                      VNDG                        DNP
# 12                      VNJS                        JMO
# 13                       NaN                        NaN
# 14                      VNBW                        BWA
# 15                      VNVT                        BIR
# 16                      VNCG                        BDP
# 17                      VNMG                        MEY
# 18                       NaN                        MWP
# 19                      VNMA                        NGX
# 20                      VNRK                        RUK
# 21                      VNRT                        RUM
# 22                      VNST                        IMK
# 23                      VNSK                        SKH
# 24                      VNTR                        TMI
# 25                      VNBL                        BGL
# 26                      VNBT                        BIT
# 27                      VNBG                        BJH
# 28                      VNBR                        BJU
# 29                      VNBJ                        BHP
# 30                      VNDL                        DAP
# 31                      VNDH                        DHI
# 32                      VNDR                        NaN
# 33                      VNGK                        GKH
# 34                      VNJI                        JIR
# 35                      VNLD                        LDN
# 36                      VNLT                        LTG
# 37                      VNMN                        XMG
# 38                      VNRB                        RJB
# 39                      VNRC                        RHP
# 40                      VNRP                        RPA
# 41                      VNSR                        FEB
# 42                      VNDT                        SIH
# 43                      VNTP                        TPU
# 44                      VNKL                        NaN
# 45                       NaN                        NaN
# 46                      VNTH                        NaN
# 47                      VNSB                        SYH
# 48                      VNTJ                        TPJ
#
#                     local_code                              home_link  \
# 0   #loc +airport +code +local                    #meta +url +airport
# 1                          NaN  http://www.tiairport.com.np/index.php
# 2                          NaN                                    NaN
# 3                          NaN                                    NaN
# 4                          NaN                                    NaN
# 5                          NaN                                    NaN
# 6                          NaN                                    NaN
# 7                          NaN                                    NaN
# 8                          NaN                                    NaN
# 9                          NaN                                    NaN
# 10                         NaN                                    NaN
# 11                         NaN                                    NaN
# 12                         NaN                                    NaN
# 13                        VNT1                                    NaN
# 14                         NaN                                    NaN
# 15                         NaN                                    NaN
# 16                         NaN                                    NaN
# 17                         NaN                                    NaN
# 18                         NaN                                    NaN
# 19                         NaN                                    NaN
# 20                         NaN                                    NaN
# 21                         NaN                                    NaN
# 22                         NaN                                    NaN
# 23                         NaN                                    NaN
# 24                         NaN                                    NaN
# 25                         NaN                                    NaN
# 26                         NaN                                    NaN
# 27                         NaN                                    NaN
# 28                         NaN                                    NaN
# 29                         NaN                                    NaN
# 30                         NaN                                    NaN
# 31                         NaN                                    NaN
# 32                         NaN                                    NaN
# 33                         NaN                                    NaN
# 34                         NaN                                    NaN
# 35                         NaN                                    NaN
# 36                         NaN                                    NaN
# 37                         NaN                                    NaN
# 38                         NaN                                    NaN
# 39                         NaN                                    NaN
# 40                         NaN                                    NaN
# 41                         NaN                                    NaN
# 42                         NaN                                    NaN
# 43                         NaN                                    NaN
# 44                         NaN                                    NaN
# 45                         NaN                                    NaN
# 46                         NaN                                    NaN
# 47                         NaN                                    NaN
# 48                         NaN                                    NaN
#
#                                        wikipedia_link  \
# 0                               #meta +url +wikipedia
# 1   http://en.wikipedia.org/wiki/Tribhuvan_Interna...
# 2                                                 NaN
# 3        http://en.wikipedia.org/wiki/Pokhara_Airport
# 4     https://en.wikipedia.org/wiki/Bharatpur_Airport
# 5      http://en.wikipedia.org/wiki/Nepalgunj_Airport
# 6                                                 NaN
# 7         https://en.wikipedia.org/wiki/Jumla_Airport
# 8        https://en.wikipedia.org/wiki/Phaplu_Airport
# 9         http://en.wikipedia.org/wiki/Simara_Airport
# 10      http://en.wikipedia.org/wiki/Janakpur_Airport
# 11                                                NaN
# 12        http://en.wikipedia.org/wiki/Jomsom_Airport
# 13       https://en.wikipedia.org/wiki/Talcha_Airport
# 14  http://en.wikipedia.org/wiki/Gautam_Buddha_Air...
# 15    http://en.wikipedia.org/wiki/Biratnagar_Airport
# 16     http://en.wikipedia.org/wiki/Bhadrapur_Airport
# 17     https://en.wikipedia.org/wiki/Meghauli_Airport
# 18                                                NaN
# 19       https://en.wikipedia.org/wiki/Manang_Airport
# 20      http://en.wikipedia.org/wiki/Rukumkot_Airport
# 21                                                NaN
# 22                                                NaN
# 23      https://en.wikipedia.org/wiki/Surkhet_Airport
# 24   https://en.wikipedia.org/wiki/Tumlingtar_Airport
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41    http://en.wikipedia.org/wiki/Sanfebagar_Airport
# 42                                                NaN
# 43      https://en.wikipedia.org/wiki/Tikapur_Airport
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47   https://en.wikipedia.org/wiki/Syangboche_Airport
# 48     http://en.wikipedia.org/wiki/Taplejung_Airport
#
#                                              keywords         score  \
# 0                                     #meta +keywords  #meta +score
# 1                                           gaucharan           875
# 2   Mount Everest, Tenzing Norgay, Sir Edmund Hillary           450
# 3                                                 NaN           800
# 4                                                 NaN           450
# 5                                                 NaN           800
# 6                                                 NaN           450
# 7                                                 NaN           450
# 8                                                 NaN           450
# 9                                                 NaN           450
# 10                                                NaN           250
# 11                                                NaN            50
# 12                                            Jomosom             0
# 13                                                NaN             0
# 14                                 Bhairahawa Airport           800
# 15                                                NaN           800
# 16                               Chandragadhi Airport           450
# 17                                                NaN           450
# 18                                                NaN           450
# 19                                                NaN           450
# 20                                   Rukumkot Airport           450
# 21                                                NaN           450
# 22                                                NaN           450
# 23                                                NaN           450
# 24                                                NaN           450
# 25                                                NaN            50
# 26                                                NaN            50
# 27                                                NaN            50
# 28                                                NaN            50
# 29                                                NaN            50
# 30                                                NaN            50
# 31                                                NaN            50
# 32                                                NaN            50
# 33                                     Gorkha Airport            50
# 34                                                NaN            50
# 35                                                NaN            50
# 36                                                NaN            50
# 37                                                NaN            50
# 38                                                NaN            50
# 39                                                NaN            50
# 40                                                NaN            50
# 41                                                NaN            50
# 42                                                NaN            50
# 43                                                NaN            50
# 44                                                NaN             0
# 45                                                NaN             0
# 46                                                NaN             0
# 47                                          Syanboche             0
# 48                                    Suketar Airport             0
#
#                  last_updated
# 0              #date +updated
# 1   2019-01-13T11:56:38+00:00
# 2   2008-12-30T09:27:04+00:00
# 3   2008-12-30T09:26:17+00:00
# 4   2018-05-11T02:50:41+00:00
# 5   2008-12-30T09:26:05+00:00
# 6   2008-12-30T09:26:25+00:00
# 7   2018-09-16T04:31:52+00:00
# 8   2018-09-16T04:31:21+00:00
# 9   2008-12-30T09:26:53+00:00
# 10  2014-12-04T21:03:11+00:00
# 11  2008-12-30T09:26:55+00:00
# 12  2019-01-11T11:45:34+00:00
# 13  2015-08-07T10:17:19+00:00
# 14  2016-05-20T10:44:58+00:00
# 15  2008-12-30T09:26:35+00:00
# 16  2010-09-01T18:41:00+00:00
# 17  2018-09-15T16:08:17+00:00
# 18  2008-12-30T09:25:57+00:00
# 19  2019-01-11T11:50:04+00:00
# 20  2019-01-11T11:43:58+00:00
# 21  2008-12-30T09:27:10+00:00
# 22  2008-12-30T09:26:29+00:00
# 23  2018-09-15T16:07:29+00:00
# 24  2018-09-15T16:06:18+00:00
# 25  2008-12-30T09:26:09+00:00
# 26  2008-12-30T09:26:39+00:00
# 27  2008-12-30T09:27:12+00:00
# 28  2008-12-30T09:27:14+00:00
# 29  2008-12-30T09:26:31+00:00
# 30  2008-12-30T09:26:41+00:00
# 31  2008-12-30T09:26:03+00:00
# 32  2017-08-19T09:10:13+00:00
# 33  2016-05-20T10:35:22+00:00
# 34  2017-08-19T09:11:15+00:00
# 35  2008-12-30T09:27:01+00:00
# 36  2008-12-30T09:26:01+00:00
# 37  2008-12-30T09:26:43+00:00
# 38  2017-08-19T09:12:30+00:00
# 39  2008-12-30T09:26:23+00:00
# 40  2017-08-19T09:13:26+00:00
# 41  2017-08-19T09:18:22+00:00
# 42  2008-12-30T09:27:16+00:00
# 43  2015-12-04T00:08:55+00:00
# 44  2013-03-01T10:51:15+00:00
# 45  2013-03-02T11:30:55+00:00
# 46  2013-03-02T14:59:21+00:00
# 47  2015-08-06T18:51:17+00:00
# 48  2015-09-06T17:04:30+00:00  >

# %% [markdown]
# # Distribution of Categorical Variables

# %%
# calculate the frequency of each type
type_counts = df['type'].value_counts()

# %%
type_counts.plot(kind='bar')
plt.title('Distribution of Types')
plt.xlabel('Type')
plt.ylabel('Frequency')
plt.figure(figsize=(10, 6))  # Set the size of the figure
type_counts.plot(kind='bar')

# Display the plot
plt.show()
